# %%
import pandas as pd
file = pd.read_excel('python-data.xlsx')     
file.head()
# Out:
#    Unnamed: 0 Unnamed: 1                Unnamed: 2 Unnamed: 3  \
# 0         NaN        NaN                       NaN        NaN
# 1         NaN        S.N                      Name      OPEID
# 2         NaN          1    John Wesley University        NaN
# 3         NaN          2  Robert B. Miller College        NaN
# 4         NaN          3        Coleman University     112446
#
#                   Unnamed: 4           Unnamed: 5  \
# 0                        NaN                  NaN
# 1                   Location  Geographic Location
# 2  High Point,North Carolina            Northeast
# 3     Battle Creek, Michigan              Midwest
# 4      San Diego, California                 West
#
#                                Unnamed: 6               Unnamed: 7  \
# 0                                     NaN                      NaN
# 1                         Enrollment Size  Carnegie Classification
# 2  4-year, very small, highly residential                      NaN
# ...
